# %%
import tushare as t
t.__version__
# Out:
# '0.8.2'

# %%
stock_df=t.get_stock_basics()
stock_df
# Out:
#          name industry area       pe  outstanding  totals  totalAssets  \
# code
# 300675   N建科院     建筑施工   深圳   117.24         0.37    1.47     56403.58
# 603707    N健友     化学制药   江苏    19.59         0.64    4.24    156624.06
# 600531   豫光金铅       铅锌   河南    46.37         8.86   10.90   1146614.38
# 600792   云煤能源     焦炭加工   云南  1720.32         9.90    9.90    601072.69
# 000933   神火股份     煤炭开采   河南    17.84        19.00   19.01   5342678.00
# 600123   兰花科创     煤炭开采   山西    11.88        11.42   11.42   2454396.75
# 000628   高新发展     园区开发   四川   391.92         1.88    3.11    344280.22
# 603612   索通发展     矿物制品   山东     6.84         0.60    2.41    318615.88
# 000603   盛达矿业       铅锌   北京   219.55         4.09    7.23    263112.75
# 600326   西藏天路     建筑施工   西藏    68.51         8.65    8.65    703034.69
# 002736   国信证券       证券   深圳    28.73        21.95   82.00  18509264.00
# 000951   中国重汽     汽车整车   山东    17.34         6.71    6.71   2460984.00
# ...

# %%
stock_df=stock_df.ix[:,['name','industry','area']]
stock_df
# Out:
#          name industry area
# code
# 300675   N建科院     建筑施工   深圳
# 603707    N健友     化学制药   江苏
# 600531   豫光金铅       铅锌   河南
# 600792   云煤能源     焦炭加工   云南
# 000933   神火股份     煤炭开采   河南
# 600123   兰花科创     煤炭开采   山西
# 000628   高新发展     园区开发   四川
# 603612   索通发展     矿物制品   山东
# 000603   盛达矿业       铅锌   北京
# 600326   西藏天路     建筑施工   西藏
# 002736   国信证券       证券   深圳
# 000951   中国重汽     汽车整车   山东
# 600958   东方证券       证券   上海
# 002500   山西证券       证券   山西
# 600734   实达集团     电脑设备   福建
# 300676   华大基因     医疗保健   深圳
# 600096    云天化     农药化肥   云南
# 603225    新凤鸣       化纤   浙江
# 002817   黄山胶囊     化学制药   安徽
# 300672    国科微      半导体   湖南
# 603886   元祖股份       食品   上海
# 000546   金圆股份       水泥   吉林
# 600971   恒源煤电     煤炭开采   安徽
# 603166   福达股份     汽车配件   广西
# 601666   平煤股份     煤炭开采   河南
# 600846   同济科技      综合类   上海
# 600295   鄂尔多斯      小金属   内蒙
# 002302   西部建设       水泥   新疆
# 000807   云铝股份        铝   云南
# 000797   中国武夷     全国地产   福建
# ...       ...      ...  ...
# 002730   电光科技     电气设备   浙江
# ...

# %%
import pandas as Pd
stock_df.to_csv('stocklist.csv')
stock_df=Pd.read_csv('stocklist.csv',index_col=0)
stock_df
# Out:
#          name industry area
# code
# 300675   N建科院     建筑施工   深圳
# 603707    N健友     化学制药   江苏
# 600531   豫光金铅       铅锌   河南
# 600792   云煤能源     焦炭加工   云南
# 933      神火股份     煤炭开采   河南
# 600123   兰花科创     煤炭开采   山西
# 628      高新发展     园区开发   四川
# 603612   索通发展     矿物制品   山东
# 603      盛达矿业       铅锌   北京
# 600326   西藏天路     建筑施工   西藏
# 2736     国信证券       证券   深圳
# 951      中国重汽     汽车整车   山东
# 600958   东方证券       证券   上海
# 2500     山西证券       证券   山西
# 600734   实达集团     电脑设备   福建
# 300676   华大基因     医疗保健   深圳
# 600096    云天化     农药化肥   云南
# 603225    新凤鸣       化纤   浙江
# 2817     黄山胶囊     化学制药   安徽
# 300672    国科微      半导体   湖南
# 603886   元祖股份       食品   上海
# 546      金圆股份       水泥   吉林
# 600971   恒源煤电     煤炭开采   安徽
# 603166   福达股份     汽车配件   广西
# 601666   平煤股份     煤炭开采   河南
# 600846   同济科技      综合类   上海
# 600295   鄂尔多斯      小金属   内蒙
# 2302     西部建设       水泥   新疆
# 807      云铝股份        铝   云南
# 797      中国武夷     全国地产   福建
# ...       ...      ...  ...
# 2730     电光科技     电气设备   浙江
# ...

# %%
stock_df.index
# Out:
# Int64Index([300675, 603707, 600531, 600792,    933, 600123,    628, 603612,
#                603, 600326,
#             ...
#             603357, 603233, 603063, 601619, 601326, 600806, 600710, 600432,
#             300686, 300682],
#            dtype='int64', name='code', length=3313)

# %%
import requests as ro
stock_code = '600660'
bs_url='http://soft-f9.eastmoney.com/soft/gp15.php?code={co}01&exp=1'.format(co=stock_code)
ct = ro.get(bs_url).text
ct
# Out:
# '<?xml version="1.0"?>\n<?mso-application progid="Excel.Sheet"?>\n<Workbook xmlns="urn:schemas-microsoft-com:office:spreadsheet"\n xmlns:o="urn:schemas-microsoft-com:office:office"\n xmlns:x="urn:schemas-microsoft-com:office:excel"\n xmlns:ss="urn:schemas-microsoft-com:office:spreadsheet"\n xmlns:html="http://www.w3.org/TR/REC-html40">\n<DocumentProperties xmlns="urn:schemas-microsoft-com:office:office">\n<Version>11.5606</Version>\n</DocumentProperties>\n<ExcelWorkbook xmlns="urn:schemas-microsoft-com:office:excel">\n<WindowHeight>10005</WindowHeight>\n<WindowWidth>10005</WindowWidth>\n<WindowTopX>120</WindowTopX>\n<WindowTopY>135</WindowTopY>\n<ProtectStructure>False</ProtectStructure>\n<ProtectWindows>False</ProtectWindows>\n</ExcelWorkbook>\n<Styles>\n<Style ss:ID="Default" ss:Name="Normal">\n<Alignment ss:Vertical="Center"/>\n<Borders/>\n<Font ss:FontName="宋体" x:CharSet="134" ss:Size="12"/>\n<Interior/>\n<NumberFormat/>\n<Protection/>\n</Style>\n<Style ss:ID="s21">\n<Borders>\n<
# ...

# %%
from modules.Utils import e2csv
open('test.csv','w').write(e2csv(ct))
bs_df=Pd.read_csv('test.csv',index_col=0)
bs_df.dropna()
# Out:
#                       17-03-31      16-12-31      16-09-30      16-06-30  \
# 报告期日期
# 货币资金(元)           7.618654e+09  7.211179e+09  7.331479e+09  7.402763e+09
# 交易性金融资产(元)        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 应收票据(元)           1.047431e+09  8.715979e+08  7.132289e+08  9.243174e+08
# 应收账款(元)           2.943981e+09  3.636343e+09  2.929705e+09  2.812072e+09
# 预付款项(元)           1.853504e+08  1.509567e+08  1.847647e+08  1.428663e+08
# 应收利息(元)           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 其他应收款(元)          1.026510e+08  1.184303e+08  1.375486e+08  1.095365e+08
# 应收股利(元)           0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 存货(元)             3.172736e+09  2.785865e+09  2.805683e+09  2.708967e+09
# 一年内到期的非流动资产(元)    2.685313e+07  1.693629e+07  1.528091e+07  1.675587e+07
# 其他流动资产(元)         1.396919e+08  1.746991e+08  1.322005e+08  1.796954e+08
# 流动资产合计(元)         1.523735e+10  1.496796e+10  1.424989e+10  1.452595e+10
# ...

# %%
from RPDownloader import *
downloadBSRP(['600660','895'])
# Out:
# 2
